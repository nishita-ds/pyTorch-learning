# %% [markdown]
# <a href="https://colab.research.google.com/github/nishita-ds/pyTorch-learning/blob/main/02-Autograd/pytorch_Autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# What is Autograd?
''' Autograd is a core component of Pytorch that provides automatic differentiation
for tensor operations. It enables gradient computation,which is essential for training
machine learning models using optimization algorithms like gradient descent.
'''
# Out:
# ' Autograd is a core component of Pytorch that provides automatic differentiation\nfor tensor operations. It enables gradient computation,which is essential for training\nmachine learning models using optimization algorithms like gradient descent.\n'

# %%
import torch

# %%
x=torch.tensor(3.0,requires_grad=True)

# %%
y=x**2

# %%
print(x)
print(y)
# Out:
# tensor(3., requires_grad=True)
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()  # y=x**2 differentiation y=2x ; x=3 ---> 2*3=6

# %%
x.grad
# Out:
# tensor(6.)

# %% [markdown]
# **Chain differentiation**

# %%
x=torch.tensor(3.0,requires_grad=True)

# %%
y=x**2

# %%
z=torch.sin(y)

# %%
print(x,y,z)
# Out:
# tensor(3., requires_grad=True) tensor(9., grad_fn=<PowBackward0>) tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668)

# %%
import math
def dz_dx(x):
  return 2* x * math.cos(x**2)

# %%
dz_dx(3)
# Out:
# -5.466781571308061

# %%
import torch

# Input
x=torch.tensor(6.7)  #Input feature
y=torch.tensor(0.0)  #True label (binary)

w=torch.tensor(1.0)
b=torch.tensor(0.0)

# %%
# Binary Cross Entropy Loss for scalar
def binary_cross_entropy_loss(prediction,target):
  epsilon=1e-8  #to prevent log(0)  1*10 ^-8 --->small number
  prediction=torch.clamp(prediction,epsilon,1-epsilon)
  return -(target * torch.log(prediction) + (1-target)*torch.log(1-prediction))

# %%
# Forward pass
z=w*x + b
y_pred = torch.sigmoid(z)

# compute binary cross-entropy loss
loss=binary_cross_entropy_loss(y_pred,y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
# Derivatives
# 1.dL/d(y_pred): loss with respect to the prediction (y_pred)
dloss_dy_pred=(y_pred -y)/(y_pred *(1-y_pred))

# 2.dy_pred/dz:prediction y_pred with respect to z(sigmoid derivaitive)
dy_pred_dz=y_pred *(1-y_pred)

# 3.dz/dw and dz/db:z with respect to w and b
dz_dw=x
dz_db=1

dL_dw=dloss_dy_pred * dy_pred_dz *dz_dw
dL_db=dloss_dy_pred * dy_pred_dz *dz_db

# %%
print(f'Manual Gradient of loss w.r.t. weight(dw):{dL_dw}')
print(f'Manual Gradient of loss w.r.t. weight(db):{dL_db}')
# Out:
# Manual Gradient of loss w.r.t. weight(dw):6.691762447357178
# Manual Gradient of loss w.r.t. weight(db):0.998770534992218

# %% [markdown]
# # Gradient using Autograd

# %%
x = torch.tensor(6.7)  #let 6.7 be any data for cgpa
y=torch.tensor(0.0)    #let 0.0 denotes not placed student

# %%
w=torch.tensor(1.0,requires_grad=True)
b=torch.tensor(0.0,requires_grad=True)

# %%
print(w,b)
# Out:
# tensor(1., requires_grad=True) tensor(0., requires_grad=True)

# %%
z=w*x+b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred=torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss=binary_cross_entropy_loss(y_pred,y)

# %%
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad,b.grad)
# Out:
# tensor(6.6918) tensor(0.9988)

# %%
x=torch.tensor([1.0,2.0,3.0],requires_grad=True)
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y=(x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
# clearing grad
# when you run backward pass multiple times ,gradient starts to accumulate
# example of above statement is as follows
x=torch.tensor(2.0,requires_grad=True)
print(x)
# Out:
# tensor(2., requires_grad=True)

# %%
y=x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
# disable Gradient tracking
# when there is no need to calculate gradient you can use this
x=torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y=x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
# when training is completed we only need forward pass and no need to call backward function
# off gradient tracking in this case to avoid memory consumption

# %%
# Option1.-- Requires_grad_(False)
# Option2.--Detach()
# Option3.--torch.no_grad()

# %%
x.requires_grad_(False)
# Out:
# tensor(2.)

# %%
x
# Out:
# tensor(2.)

# %%
y=x**2
y
# Out:
# tensor(4.)

# %%
x=torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
z=x.detach()
z
# Out:
# tensor(2.)

# %%
y=x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y1=z**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# but y1.backward() throw error

# %%
x
# Out:
# tensor(2., requires_grad=True)

# %%
with torch.no_grad():
  y=x**2

# %%
y
# Out:
# tensor(4.)
